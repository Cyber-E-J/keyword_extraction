# %%
file = open("test_v3","r")
lines = file.readlines()
lines
# Out:
# ['shy find say rather call text ask check \n',
#  'watch ttyl talk machine funny american hahaha one idk show turn check like gr8 \n',
#  'make guess help pick right first prob four send like third two \n',
#  'home tonight everything want soon worry mean love \n',
#  'thing right call tea spy friday busy enjoy forget lose eat ready nope pleasure 18th free back nice trip check wait way strange tomorrow mean \n',
#  'guess cuisine want take try 😎 guy see option meet yesterday prove atm 🙉 pass sound join tired obstacle wait feel interesting end today yaaaawn whoever come \n',
#  'sry right thanks like buy read problem second one clothes srsly gr8 3 obvious 2 check lot love book everything come \n',
#  'boss cut hate keep bloody time fall hour \n',
#  'town complain scarf help thanks want understanding need like care \n',
#  'parent tell say thanks take brother eric come \n',
#  'beacuse note want take ask try need friday 1st let \n',
# ...

# %%
total_num = 0
for line in lines:
    num = len(line.split())
    print(num)
# Out:
# 8
# 14
# 12
# 8
# 25
# 27
# 21
# 8
# 10
# 8
# 10
# 12
# 10
# 4
# 13
# 11
# 4
# 11
# 29
# 7
# 29
# 17
# 13
# 8
# 16
# 28
# 3
# 9
# 11
# 27
# 3
# 13
# 10
# 3
# 10
# 2
# 11
# 8
# 7
# 13
# 22
# 8
# 25
# 2
# 8
# 5
# 24
# 11
# 4
# 11
# 15
# 16
# 6
# 4
# 5
# 9
# 4
# 5
# 12
# 5
# 1
# 14
# 4
# 8
# 19
# 7
# 5
# 16
# 17
# 9
# 8
# 6
# 9
# 6
# 22
# 7
# 6
# 12
# 9
# 12
# 5
# 28
# 8
# 13
# 7
# 11
# 15
# 8
# 16
# 7
# 1
# 16
# 12
# 2
# 7
# 1
# 12
# 3
# 5
# 8
# 23
# 5
# 4
# 4
# 8
# 11
# 6
# 0
# 3
# 31
# 17
# 14
# 7
# 27
# 23
# 9
# 13
# 4
# 5
# 29
# 7
# 13
# 3
# 8
# 3
# 9
# 5
# 14
# 8
# 9
# 5
# 22
# 16
# 17
# 7
# 11
# 16
# 5
# 3
# 6
# 1
# 16
# 9
# 1
# 2
# 7
# 7
# 14
# 13
# 9
# 3
# 18
# 20
# 14
# 11
# 24
# 1
# 24
# 5
# 3
# 8
# 10
# 5
# 5
# 22
# 14
# 12
# 8
# 19
# 27
# 13
# 10
# 7
# 5
# 5
# 4
# 11
# 5
# 3
# 8
# 4
# 22
# 23
# 8
# 5
# 4
# 10
# 17
# 7
# 7
# 11
# 7
# 18
# 22
# 15
# 31
# 10
# 7
# 5
# 11
# 7
# 23
# 24
# 14
# 23
# 17
# 6
# 16
# 10
# 14
# 9
# 5
# 12
# 11
# 5
# 20
# 17
# 17
# 10
# 5
# 14
# 6
# ...

# %%
line = file.readlines()[10]

# %%
len(line.split())
# Out:
# 10

# %%
len(line)
# Out:
# 52
