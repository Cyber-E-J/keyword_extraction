# %%
import stanza
nlp = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos,lemma,depparse,ner' ,download_method = None)

print("import success\n")

def open_file(filename):
    file = open(filename,"r")
    lines = file.readlines()
    dialogues = []
    for line in lines:
        dialogue_in = line.find("\"summary\"") 
        if (dialogue_in!=-1):
            dialogues.append(line.strip()[12:-2])
    return dialogues

open_file("test.json")

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
new_stop_words = ['file_gif','file_other','\'s', '\'m', 'file_photo', 'u' , 'urgh', 'r' , 'haha' ,
                  'ok', 'eh' , '\'re', 'yeah', 'file_video' ,'oh' , 'xd' , 'yes' , 'bye' , 'yup',
                  'lol' , 'be' , 'hey', 'sure' ,  'yep' , 'know', 'really' , 'sorry', 'that', 'wtf',
                  'get', 'go' , '' , 'yea' , 'alright' 
                 ]
for word in new_stop_words:
    stop_words.add(word)

# %%
key_deprel = ['root', 'csubj', 'nsubj','xsubj', 'cop', 'vmod','dobj' ,'iobj', 'pobj']
def get_keyword_from_sentence(sentence):
    keywords = []
    doc = nlp(sentence)
    for sent in doc.sentences:
        entities = sent.entities
        entities_name = [entity.text for entity in entities]


        for word in sent.words:
            try:
                word_lemma = word.lemma.lower()
            except:
                word_lemma = ''
            if(
               (word.deprel in key_deprel  # select word with parsing
                or 
                word_lemma in entities_name # word is an entity
               )

               and word.text.lower() not in stop_words # delete stopword
               and word_lemma not in stop_words

               ):
                # keywords.append(word.text.lower())
                keywords.append(word_lemma)
    return keywords



def get_keyword_from_dialogue(dialogue):
    keywords = []
    for sentence in dialogue:
        # start_pos = sentence.find(":")
        # sentence = sentence[start_pos+2:]
        for word in get_keyword_from_sentence(sentence):
            keywords.append(word)
        clean_repeat_keywords = list(set(keywords))
    return clean_repeat_keywords

def get_keyphrase_from_file(file):
    dialogues = []
    for dialogue in file:
        sentences = dialogue.split(". ")
        dialogues.append(sentences)

    keyphrase = []
    for dialogue in dialogues:
        keyphrase.append(get_keyword_from_dialogue(dialogue))
    return keyphrase

def get_keyphrase(filename):
    file = open_file(filename)
    # length = len(file)
    length = 20
    print("file length = {}".format(length))


    keyphrase = []
    for i in range(0, length, 10):
        output_2_txt(output, get_keyphrase_from_file(file[i:i+10]))
        print("dialogue {} to {} parsed".format(i,i+9))

    return keyphrase

def output_2_txt( output, file):
    for line in file:
        for word in line:
            output.write(word+' ')
        output.write('\n')

output = open("output","w")

get_keyphrase("test.json")

# %%
dialogue = ["Hannah needs Betty's number but Amanda doesn't have it."," She needs to contact Larry."]
get_keyword_from_dialogue(dialogue)
# Out:
# ['number', 'hannah', 'amanda', 'need']

# %%
file = open_file("test.json")
dialogues = []
for dialogue in file:
    sentences = dialogue.split(". ")
    dialogues.append(sentences)
dialogues
# Out:
# [["Hannah needs Betty's number but Amanda doesn't have it",
#   'She needs to contact Larry.'],
#  ['Eric and Rob are going to watch a stand-up on youtube.'],
#  ["Lenny can't decide which trousers to buy",
#   'Bob advised Lenny on that topic',
#   "Lenny goes with Bob's advice to pick the trousers that are of best quality."],
#  ['Emma will be home soon and she will let Will know.'],
#  ['Jane is in Warsaw',
#   'Ollie and Jane has a party',
#   'Jane lost her calendar',
#   'They will get a lunch this week on Friday',
#   'Ollie accidentally called Jane and talked about whisky',
#   'Jane cancels lunch',
#   "They'll meet for a tea at 6 pm."],
#  ['Hilary has the keys to the apartment',
#   'Benjamin wants to get them and go take a nap',
#   'Hilary is having lunch with some French people at La Cantina',
#   'Hilary is meeting them at the entrance to the conference hall at 2 pm',
#   'Benjamin and Elliot might join them',
#   "They're meeting for the drinks in the evening."],
#  ['Payton provides Max with websites selling clothes',
#   'Payton likes browsing and trying on the clothes but not necessarily buying them',
#   'Payton usually buys clothes and books as he loves reading.'],
#  ['Rita and Tina are bored at work and have still 4 hours left.'],
#  ["Beatrice wants to buy Leo a scarf, but he doesn't like scarves",
#   'She cares about his health and will buy him a scarf no matter his opinion.'],
#  ["Eric doesn't know if his parents let him go to Ivan's brother's wedding",
#   'Ivan will talk to them.'],
#  ['Wanda wants to throw a party',
#   "She asks Gina to borrow her father's car and go do groceries together",
#   'They set the date for Friday',
#   ''],
#  ['Martin wrote a short review and won 2 cinema tickets on FB',
#   'Martin wants Aggie to go with him this week for the new film with Redford.'],
#  ['Charlee is attending Portuguese theater as a subject at university',
#   'He and other students are preparing a play by Mrożek translated into Portuguese.'],
#  ['Ella rented a car, this makes things much faster for her and Tom', ''],
#  ['Paul is going to share his Netflix account with Luke',
#   'In exchange Luke is going to contribute to the subscription',
#   'Paul will send Luke his bank details',
#   'Paul is on vacation with his girlfriend till tomorrow.'],
#  ['Greg and Betsy have a lot of work today, so they cannot pick up Johnny from the kindergarten',
#   "However, it's Greg's turn to do it",
#   'Greg will try to find a solution.'],
#  ['Ethan, Toby and Marshall are making fun of Scott.'],
#  ['Igor has a lot of work on his notice period and he feels demotivated',
#   'John thinks he should do what he has to do nevertheless',
#   ''],
#  ['Clara is rewatching Dear White People and strongly recommends it to Neela.'],
#  ['Mike took his car into garage today',
#   "Ernest is relieved as someone had just crashed into a red Honda which looks like Mike's",
#   ''],
#  ["Beth wants to organize a girls weekend to celebrate her mother's 40th birthday",
#   "She also wants to work at Deidre's beauty salon",
#   'Deidre offers her a few hours on Saturdays as work experience',
#   'They set up for a meeting tomorrow.'],
#  ['Gloria has an exam soon',
#   'It lasts 4 hours',
#   'Emma sent her a link to a website with some texts from previous years so that she can prepare for the exam better.'],
#  ['Adam and Karen are worried that May suffers from depression',
#   'Karen will call her friend who is a psychologist and ask for advice',
#   ''],
#  ['Mark lied to Anne about his age', 'Mark is 40.'],
#  ["Next week is Wharton's birthday",
#   'Augustine, Darlene, Heather and Walker want to buy him a paper shredder',
#   'Walker will make sure if Wharton really wants it',
#   ''],
#  ["Kelly is scared of sculpture garden figures in Finnland, she finds figure's faces morbid",
#   "For Ollie it's Nagoro village in Japan, it's creepy",
#   ''],
#  ['Selah called a person that did not pick up.'],
#  ['Bella and Eric dismissed a request of a client',
#   'Their boss appreciated the decision',
#   'He brings in new clients.'],
#  ['Emma is about to take a nap in the back of the bus to New York',
#   'Ben and Emma will be there around 4.30 pm',
#   'Ben will wake Emma up 15 minutes prior to their arrival.'],
#  ['Jesse, Melvin, Lee and Maxine are going to take part in the Christmas charity action of the foundation called Refuge, which helps women and children who escape from abuse.'],
#  ['Mary ran out of money', 'Carter is going to lend her some in an hour.'],
#  ['Paula helped Charlotte with correct pronunciation of \\"Natal lily\\".'],
#  ['Jack and May will drink cocktails later.'],
#  ['Margaret is suffering from a terrible headache and wants Jack to buy her some painkillers',
#   ''],
#  ['Serge is on his way to pick up the film equipment for the shooting tonight',
#   'Andrei and Serge are late with a large payment to the company',
#   'Serge and Andrei will try to use the credit card to pay the company.'],
#  ['Martina advises against getting a hamster', ''],
#  ['Mary has played DA Inquisition',
#   'Lucas has played DA II',
#   'Daniel started playing DA Inquisition.'],
#  ["Judy thinks she's always attracted to bad guys."],
#  ['Riley and James watch Chloe on tv undergoing a metamorphosis.'],
#  ['Tina will catch the evening flight back home',
#   'Ala is on her way to the meeting',
#   'She will let Tina know how it went.'],
#  ['Sebastian is very happy with his life, and shares this happiness with Kevin.'],
#  ["Son is coming to see his parents' this weekend."],
#  ['Ola is in Cuba and is enjoying her trip',
#   'She has problems with connectivity there',
#   'Momo has recovered from her injury',
#   "Ola doesn't like the clothes in Cuba",
#   'Ola will try to find a blouse for mum in Cuba, as Kate suggested.'],
#  ["Mike will ask Mary for John's new number."],
#  ["Joseph has sent Ella a photo of Wujek Janek's twin baby cows",
#   'Ella is delighted.'],
#  ['Josh thinks Stephen accidentally took his notebook',
#   'Jack has it and will bring it tomorrow.'],
#  ['Adele got a new biscuit Labrador Chewy that is 4 months',
#   'Her cats keep their distance, and Poppy and Lulu seem to mother Chewy and Speedy wants to play.'],
#  ['Kristian and Tabora are playing a game about what they like best.'],
#  ['Cathy will pick up her glasses tonight at 10.'],
#  ['Petra is very sleepy at work today, Andy finds the day boring, and Ezgi is working',
#   ''],
#  ['Nick finds Jane pretty and invites her for a drink to get to know her better',
#   'Jane rejects Nick and is unpleasant to him',
#   'Nick suggests Jane to forget about their conversation.'],
#  ["Julia knew Tim was gay, while Adam and Nate didn't", ''],
#  ['Lilly will be late',
#   'Gabriel will order pasta with salmon and basil for her.'],
#  ['Celine is not at home, but she will call Cara before visiting her.'],
#  ["Derek will be at Craig's in 20 minutes to help him with his malfunctioning computer."],
#  ['Abigail is not going to take a stroll with the little ones',
#   'Her smog alert app is showing that the norms have been exceeded by 30% today.'],
#  ["Paul will buy red roses following Cindy's advice."],
#  ["Jenny has left her credit car at the Mary's shop."],
#  ["It's Tom's birthday",
#   "Lara and Gary will come to Tom's place about 5 pm to prepare everything before Tom gets back home at 5:30",
#   'Gary has already paid for the cake - Lara will pick it up and she will also get the balloons',
#   ''],
#  ['Paul is late for a meeting with Laura and she refuses to wait any longer.'],
#  ['Salma and Hugh like cat memes.'],
#  ['Todays results show that Matt and Oliver got into Stanford University, Peter did not',
#   ''],
#  ['English classes were cancelled because Smith called in sick and replacement could not be found.'],
#  ['Brandon has lost his credit card and blocked it in the bank',
#   'It will take some time before he gets a new one, and he needs money',
#   'Luke is broke, but Ian will lend Brandon some money.'],
#  ['Patrycja and Inez enjoyed the Italian evening',
#   'Gosia chose a great place',
#   "Alicja hasn't been to the new restaurant",
#   'They all want a Korean evening on Wednesday in two weeks time.'],
#  ['Ana wants to visit grandma tomorrow',
#   'Catherine will go with her',
#   'She will call Anna when she wakes up.'],
#  ['Edson is booking his ticket now.'],
#  ["Jane wants to leave at 4.30 instead of 5 because Google Maps suggests the 300 km drive should take them at least 3 hours and she doesn't want to be late",
#   'She will wait for Steven at the main entrance.'],
#  ['Suzanne is at work and is having a break now',
#   'Morgan invites Suzanne to a concert of Maroon 5 which takes place next week at the Hulu Theatre at Madison Square Garden',
#   'Suzzanne agrees.'],
#  ['The last one Julia read was Die again from 2014',
#   "There's going to be a meeting with Tess organized by the city library",
#   ''],
#  ["Ali left his wallet at Mohammad's place",
#   "Mohammad'll bring it to uni tomorrow."],
#  ['Linda and Laura are going to an Italian restaurant tomorrow.'],
#  ["Anna organises a birthday's party on the 6th of November at 19:30."],
#  ['Mia is going out after work tonight with her female friends',
#   'If she wants, Elliot will come and pick her up.'],
#  ["Jayden explains Brennan why she doesn't want to be pregnant."],
#  ['USA won last night', 'England is playing against Croatia tomorrow at 2.'],
#  ['John forgot his wallet',
#   'He wants Ela to give it to him outside in 10 minutes.'],
#  ['Mark told his sister that Mary is doing an online job',
#   "Mark's sister is contacting people to confirm it",
#   "Mark thinks she's jealous",
#   "Mary hates Mark's sister."],
#  ['Fiona wants to prepare dinner for Chris',
#   "She is thinking of Tina's tart",
#   'She will help her make it.'],
#  ['Annette is sick',
#   'James is going to the Jesus bar',
#   "Oli couldn't find anyone near the bar."],
#  ['Ryan and Sebastian are worried about the political situation in Ukraine.'],
#  ['Finn and Zadie are going to Elephant and Castle tomorrow at 2',
#   'They will meet at the main entrance.'],
#  ["Jacob hasn't listened to the song Harry sent him 3 days ago",
#   'Jacob will do it later tonight and let Harry know what he thinks.'],
#  ['Ray is locked in the room from the outside and he has to pee',
#   "Max's roommate will come and let him out."],
#  ['Kim is about to tell mom that Harry bought a new sofa, and he needs grey pillows.'],
#  ["Josh wants to buy a tablet and doesn't know which brand he should choose",
#   'According to Brian, other brands are better than Apple and he can get a Samsung tablet cheaper',
#   'Josh will call Brian after work to talk about it.'],
#  ["Nathalie, Olafur and Zoe are planning the New Year's Eve",
#   'Nathalie wants something classy',
#   "Olafur doesn't like opera",
#   "They want to go to the Breakfast at Tiffany's party in Soho."],
#  ["Frank tries to encourage Andy to learn for the tomorrow's quiz."],
#  ['Kim needs to get some fresh fish in Warsaw',
#   'Kim will ask at restaurants about their source',
#   "Kim is planning something special but won't share any details with Margot for now."],
#  ['Tom will meet Ben in the Oval Room at 2pm and tells him to bring the papers',
#   ''],
#  ['Ashleigh got the job.'],
#  ['Danna has a boring weekend and is watching TV',
#   'Reed is in bed',
#   'He has a free day tomorrow.'],
#  ['Alivia has been taciturn lately',
#   'She was trying to write her thesis',
#   "She can't focus on writing",
#   "She'll try to follow Antonio's advice to start writing without overthinking."],
#  ["Maddie will buy a white bread and apples on John's request."],
#  ["Elliot can't talk to Jordan now, he's busy",
#   "He'll call him back at 8 pm",
#   "Jordan is going to Brad's funeral",
#   'He had liver cancer.'],
#  ['Flo cannot get an appointment at the salon until the 6th',
#   "Flo worries she's going to be gray",
#   'Flo will have to get a touch-up kit at Tesco.'],
#  ['Rob is doing shopping at the grocery store',
#   'Ann ordered him to buy a cucumber, some tomatoes, bananas and apples.'],
#  ["It's been very long since Melany last had sex",
#   'Marvin made an inappropriate joke about it.'],
#  ["Eric, Samantha and Noah's professor is commenting a recent scandal on the news",
#   ''],
#  ['According to Jacky, David did the right thing taking the blame',
#   'They will talk when Jack comes back home.'],
#  ['Rick and Helen are in Cancun',
#   "They're flying to Havana in two days",
#   'Chris and Rick will talk on Skype at 3 PM in Mexico.'],
#  ['Ying sent a photo of his 10 years challenge to Helen, Norma and Zazu.'],
#  ['Daniel will see Missy after 6 for drinks.'],
#  ['Adelle has to clean the hamster cage after school.'],
#  ['Maya will buy 5 packs of earplugs for Randolph at the pharmacy.'],
#  ['David is coming home for Christmas next week',
#   ' Jane has no idea what to buy their father so David is going to order an ipad online.'],
#  ['Isabella is grateful to Betty for sharing the information about her work yesterday',
#   'Isabella offers Betty her company, should Betty want to do something together.'],
#  ["Hollie says hello to Amy, but Amy is busy working and can't chat right now."],
#  ['Alex will go swimming toghether with Huda in two hours', ''],
#  ['Janet, Nicole, Alison, Arlene, Leslie, Ros, Eric and Sue are all complaining about Donald Trump and his absence at the ceremony',
#   ''],
#  ['Rashi is confused by too many career choices',
#   'Teacher advises him to choose something he has passion for and what interests him.'],
#  ['Corbin reported to the department in charge of school violence that his friend has been beaten.'],
#  ['Marta needs help with the PC',
#   "On Joel's advice, she will contact Cynthia or Elena as they might know someone",
#   ''],
#  ["Ann doesn't know what she should give to her dad as a birthday gift",
#   "He's turning 50",
#   'Fiona tries to help her and suggests a paintball match.'],
#  ['Fatima is worried about Jenson and Alene',
#   'Alene has issues',
#   "Lincoln doesn't want Fatima to worry about others too much."],
#  ['Bob is going to help Lisa clean the house, he will clean the bathroom', ''],
#  ['luke and martial want to help the team and play despite their injuries',
#   "They will meet at carrington and go to the coach's office."],
#  ['Emily and Julie wish Merry Christmas to each other.'],
#  ["Ricky's new neighbours are nice but loud",
#   'They own a parakeet that makes a lot of noise throughout the night.'],
#  ['Sandra and Brenda used to work together in the clothes factory 25 years ago',
#   'Sandra still lives in Kings Norton',
#   'Brenda lives in Stoke now',
#   'Her husband Bill died 5 years ago',
#   'They will meet in Birmingham for a lunch next Saturday about 11',
#   "They want to organize a reunion for the Lister's girls",
#   ''],
#  ['Joan and John are going to watch \\"A Star is Born\\" on Thursday around 8 p.m.'],
#  ['Donna will pay George a visit tonight to discuss a personal matter.'],
#  ['Louis finishes the conversation with Fabian because his mother is calling.'],
#  ["Irene will take Crystal's son shopping for clothes."],
#  ['Tony sent a photo of his cat to Amy and Lucas.'],
#  ["Matt got a ticket for Dawid Podsiadlo's concert", 'Thomas is going, too.'],
#  ['Some girls had to undress because they had been pushed into the pool.'],
#  ['Mico and Jeff will go to the village party', 'Jeff will drive.'],
#  ["Paul can couch the game on Saturday as Matthew hasn't found anyone to do that yet",
#   ''],
#  ['Freddy will pick Luke up at about 3:15 pm.'],
#  ['Ryan and Jack are going to the casting for a dance show.'],
#  ['Joanne is going to go back home to France for the holidays',
#   "She's going to cheer her mum up because her parents separated a few months ago",
#   'Evelyn offers Joanne to spend Christmas together if she brings her mum over here',
#   ''],
#  ["Raul's had a bad night and day", ''],
#  ["Angie's having an appointment with Doctor McCormick in an hour",
#   'She has strong abdominal pain.'],
#  ['Kelvin and the other class members will discuss the time for their CAT 2 and share their decision with Naheeda soon.'],
#  ['Karen wants something cheaper than sushi for lunch',
#   'Linda, Ronnie and Karen will get takeout pasta boxes to the park.'],
#  ['Marty thinks she has sprained her ankle',
#   'Marty wants to go to the doctor tomorrow',
#   'Christine will pick up Marcel from school today',
#   'Tomorrow Christine will take Marcel to school and Marty to the doctor',
#   'Marty will call the school',
#   'Christine and Marty will meet around 4',
#   ''],
#  ['Peyton is expecting Cameron to bring the video game',
#   'Cameron will probably be out for another week.'],
#  ["Alicja's job interview is tomorrow", 'She will inform Willyx how it goes.'],
#  ['Paul forgot about his physiotherapy and he will schedule a new appointment',
#   'Emma will be home after midnight, so Paul will prepare some food for her.'],
#  ['Sean overslept again.'],
#  ["Chris and Tom are planning a meeting at Chris' place",
#   'Chris has a Jacuzzi in his garden',
#   'Chris has WiFi and can bring his TV outside',
#   "Tom has a low internet limit whenever he's outside of Ireland."],
#  ["Ela is not taking Harry's phone calls",
#   "Cindy calls Ela at Harry's request."],
#  ["Mike didn't have time to take the dog for a walk, so Adam will take it with him."],
#  ['Murphy is going to Poanań on Tuesday and coming back on the same day in the afternoon.'],
#  ['Gaia has 6 exams this semestre', 'One is very difficult.'],
#  ['Mr',
#   'Williams invites Ms',
#   'Blair for a coffee',
#   'They will go to her favourite coffee place near the square in a side alley at 2 p.m.'],
#  ["Serena's skin condition is fine now and she doesn't have to take medication",
#   'Tina has a similar condition but takes medication on a daily basis',
#   'Tina can call Serena if she has questions',
#   ''],
#  ["Kristina, Estefania and Jannette are watching America's Top Model."],
#  ['Daniel is going to Bologna today',
#   'He has to transfer there for a further flight',
#   'He will stay at the airport for two hours',
#   'Simone will visit Marco in December.'],
#  ['Mike will call Dale back in 2 hours.'],
#  ['Timmy had a bad day at work',
#   "Timmy will bring some wine to Gemma's bbq at the weekend."],
#  ['Pat will arrive at around 9 pm',
#   'Bart will open the door and work in the morning from home',
#   ''],
#  ['Erin will meet Ashley in the restaurant for the interview', ''],
#  ['Maria, Kate, Tommy and Sam are going to a conference',
#   'Tommy will use Prezi instead of Power Point',
#   'He has a Prezi subscription for $10 a month.'],
#  ['Maxwell pays Jeanice for 8 hours of babysitting and is grateful he found her',
#   'His son argued with a friend at school, and got agressive when the teacher reacted',
#   "Jeanice hasn't noticed if he has acted strangely recently",
#   'Maxwell and Jeanice can grab a coffe some time to discuss all the issues',
#   ''],
#  ['Mike, Tom and Ben will go for a beer.'],
#  ['Leah met a creepy guy last night at a poetry reading',
#   'He knew she speaks German and named all the friends who went to a past event with her',
#   "She didn't tell him any of this",
#   'He googled her before',
#   'Leah had liked a post mentioning him 2 weeks earlier',
#   ''],
#  ["Nicky has just left Sam's place", 'Her phone is off.'],
#  ['Ken is trying to play a prank on Greg.'],
#  ['Tom arrived safely, but without his luggage.'],
#  ['The university is throwing a carnival party for kids.'],
#  ['Ian is looking for his green folder',
#   "Sophie hasn't seen it but maybe Alex will know."],
#  ['Simon will talk to Adrian in 5 minutes.'],
#  ['Jen is about to break up with her boyfriend',
#   'Jane knew from the beginning that they were not a good match',
#   'Jane is going to support Jen.'],
#  ["Poppy is not going to be home tonight but she won't reveal the reason to Dean",
#   "She won't be making dinner so Dean has to get something on his way home."],
#  ['Gab wants to meet Kat in real life',
#   "Kat doesn't like Gab's insisting so she won't to talk to him at all."],
#  ['Agatha is proud of herself because she has finished her presentation in Economics',
#   'She is very interested in Economics.'],
#  ['Imagine Dragons have a concert at ABC Theatre on 12 July',
#   'Sally wants to go with Tim',
#   'She bought tickets, they cost 70.'],
#  ["Andrew has discovered an issue with Bez's car in her absence but it seems to be ok",
#   'He will also take care of her plants until she is back on the 21st',
#   ''],
#  ['Laura is going to visit her parents next Saturday',
#   'Keith might make a lasagne for her',
#   "Laura's mom has a birthday gift for her",
#   ''],
#  ['Pegah is in class till 15:00',
#   'She will work from 17:00 till around 21:30',
#   'She will be back at 22:00',
#   'Miriam invited people over and wants Pegah to come',
#   'Pegah will have a cup of tea with her when she gets back',
#   'Miriam will save Pegah some wine.'],
#  ["Robert will pick up floating balloons for Tom's birthday."],
#  ['Shelly is voluntering at a food shelter and asks if others do some volunteer work',
#   'Tracy is not into that, but Jody always does some charity for Christmas.'],
#  ["Jim will check out Max's latest music project when he gets home."],
#  ['Kane recommends the new 30 Seconds to Mars album to Shannon.'],
#  ['Andy is going to visit Paul in about 1 hour.'],
#  ['Caroline and Megan play a guessing game - they need to guess which film a quote comes from.'],
#  ['Josh should check the email from Ron', ''],
#  ["Phoebe cannot go out today because she broke a bottle of her mother's expensive perfume",
#   "Phoebe's mother is angry",
#   'The smell of the perfume in the apartment is too intense now.'],
#  ['Rob and Eve will meet on Sunday morning to go to the shops',
#   'Eve has something to do at about 3',
#   ''],
#  ['Betty shares a photo of a man with a cat with Sandra',
#   "Sandra's ex wants to get back",
#   'She misses him',
#   'Betty comes over with wine at 6.'],
#  ['Anna likes a new app in which you can virtually try on clothes',
#   'Peter is not quite convinced it is necessary.'],
#  ["Dan's had an injection with anaesthesis because he got swollen",
#   "He feels it's not working though and it still hurts him."],
#  ['Archie is arriving from Southampton around midnight',
#   'He will travel by bus',
#   'He will call Judah.'],
#  ['Chloe will watch the serious recommended by Biwott at the weekend.'],
#  ["Lauren want's to have a small tattoo above her ankle."],
#  ['The toilet upstairs is blocked again',
#   "Wendy and David can't afford the plumber as Wendy spent the money on her sister's birthday present."],
#  ["Kaylen wants to know if there is left-hand traffic in Rowen's country",
#   'He confirms there is',
#   "She thinks she wouldn't be able to drive there."],
#  ["Tom wants to go to Robinson Crusoe's island."],
#  ['Titus agrees to help Emely with a language exercise',
#   'Emely sends Titus a photo of the filled out exercise, but he has trouble reading it.'],
#  ["Marco will read Aldo's 12 page article that he spent 2 weeks writing."],
#  ["Harris' friend, Aoki, who lives in Michigan, died yesterday",
#   "Harris hasn't seen her for a few months."],
#  ["Hannah's New Year's resolutions are: work out, cook for herself, start dating",
#   "Brooklyn didn't make any",
#   'In the past she had, but she never fulfilled them',
#   ''],
#  ['Trevor got Abigail pregnant',
#   'When they were having sex without protection her father, a church pastor, kicked Trevor in the butt and Trevor came inside Abigail',
#   ''],
#  ['Jessica posts a lot regarding subjects she does nothing about in reality',
#   'Julia posts in a more genuine way',
#   'But Hillary thinks she does it to death and lacks real life.'],
#  ['Miranda called Tom yesterday and spoke to him in a sweet way',
#   'Anne is angry with her because Anne is dating Tom.'],
#  ['Barbara and Eva described their dietary requirements in the website given by Ella.'],
#  ['Sarah will arrive to New York on Thursday',
#   'Joshua expects to get a gift.'],
#  ['Allison has got a scholarship.'],
#  ["Sam won't finish work till 5",
#   'Sam is bringing him over about 9 am',
#   'Sam will see Abdellilah in the morning',
#   ''],
#  ['Betty and Phil are meeting at 6.30 to watch a thriller at the movies',
#   "They will have dinner at Phil's afterwards."],
#  ['Robert has a new phone number starting with 304',
#   'Robert has lost his job and is looking for a new one',
#   'Serge offers to pass on Roberts CV to a contact',
#   ''],
#  ['Lily spent an amazing night with Thomas',
#   'Thomas is Romanian and comes from a very rich family.'],
#  ['Sam wants to buy a custom dress as a surprise for his wife',
#   'It should be black and elegant',
#   'The store employee sent him some pictures for reference',
#   'Sam decided on the features he likes',
#   "His product number is 898998 and he will place the order on the company's website."],
#  ["Kamden hasn't used social media recently",
#   "He uses messenger only and wants to get Mckinley's photographs."],
#  ['After work, Mike is going to go to the gym and then home',
#   'He invites Jason to bring some food and come over',
#   'They can play 2 on ps4.'],
#  ['Linda got a new job and is moving to Ohio for 6 months',
#   'Her brother will stay at her current apartment',
#   "Daisy will come by Linda's place to meet her and help her pack as she is too busy to go out."],
#  ['Hayden must write her thesis in 1 month',
#   'She wonders what degree course would be the most beneficial for her',
#   "She's interested in African studies",
#   'Hayden claims she could be a flight attendant as she can swim and knows foreign languages.'],
#  ['Alan has found some cinnamon whiskey and sends Robert photos of it', ''],
#  ['Yaz and Mary are meeting tonight around 6 and going for the slimming club together',
#   'They expect to be scolded for eating too much',
#   ''],
#  ["Ellie's class is in 342 on the second floor."],
#  ['Nathan and Aaron are discussing a video which Nathan sent', ''],
#  ['William is coming back in 5 minutes as he had to queue for 20 minutes.'],
#  ['Jake reserved 3 tickets for tomorrow 7 pm', 'He got 30% discount.'],
#  ['Freddie, Kelly, Jim, Greg, Bob, Mike, Mary, Alan and Nancy are watching different shows on Netflix.'],
#  ['Sonia is going to San Sebastian in a month',
#   'Toni enjoyed her the airbnb place there',
#   "Sonia isn't convinced about it and will let Toni know."],
#  ['Malik and Samanta want to lose weight',
#   'They will try to keep a diet, keto or paleo, and go for runs together.'],
#  ['Derek closed some deals today', "Phil didn't manage to do it."],
#  ['People are photoshopping Timothée Chalamet into artworks',
#   'Dominic and Nova agree that he looks like a 19th century man.'],
#  ['Peter has been working out at the gym near their office lately to improve his health',
#   'Lisa is considering working out and eating better to be healthier.'],
#  ["Julia broke Tom's cup, which made him sad", 'She will buy him a new one.'],
#  ['The CSS tests for the hockey players are today and will last 3 hours, starting 5pm',
#   "Hank will bring his son and Don's son as well",
#   'Don is glad.'],
#  ['Jessica bought a table, six chairs, a vase and a pile of clothes and the second hand shop downtown',
#   'She paid 70 euros for everything',
#   ''],
#  ['Abigail and Damien are going to church on Sunday',
#   'Damien has to put on a coat and tie.'],
#  ['Lucian is not at home',
#   'Desiree wants Lucian to keep her pasta in the microwave.'],
#  ['Doug has a cool pair of shoes.'],
#  ["Tessa doesn't like Chloe texting her boyfriend, Jim Andrews",
#   "Jim is Chloe's co-worker so Chloe needs to communicate with him."],
#  ['Emily, Kate and Marta are going to the Pub X at the central station today for a drink.'],
#  ['Jane, Anne and Ella have been to La Perle',
#   'Jane ate cheesecake and got an allergic reaction',
#   'They are getting out of ER',
#   ''],
#  ['Railey will buy Tiffany a burger.'],
#  ['Ariana will do shopping in Midtown', "Aviana can't join her."],
#  ["Connor bought his halloween costumes at Value Village where Jane plans to get her and her sister's costume."],
#  ["Today Mary didn't go to school, she stayed at home."],
#  ["Elena is wearing the red jacket and Jeffrey can't see her nor Tom."],
#  ['Sophia apologizes to Mason', 'She sends him a kiss photo on his request.'],
#  ['Steffen twisted his ankle yesterday and needs a lift to the infinity pool',
#   "Irene's car probably won't make it up the hill, so they'd have to park at the bottom and hike up",
#   "Mr.Budd should make it up the hill since it's a 4-wheel drive."],
#  ['Jake, Florence, Margot and others are going on a research trip to Swazi',
#   "The name of the country was changed last year and it's now Eswatini."],
#  ["Christine is sick and won't come to school tomorrow",
#   'Annie will leave Theraflu sachets in a mailbox',
#   "Christine doesn't want to get her sick."],
#  ['Jill called Sarah', 'She also sent her some old pictures', ''],
#  ['Peter starts his new job on the 6th',
#   'Peter wanted a free babysitter',
#   'Aggie will arrange for a babysitter',
#   ''],
#  ['Aimee is looking for Maryam.'],
#  ['George, Robert and Paul are going to play basketball on Friday at 7',
#   'Yousuf will be late.'],
#  ["Rory wants Mitch to take Bill and Sammy and they'll chip in for gas",
#   'Mitch will be leaving Sunday, the 29th to get there by 9 am on Monday',
#   'Bill will arrive around 10 am Sunday and Joanna will be picking him',
#   'Mitch will meet Bill after.'],
#  ['Jones and Angelina will meet in town in the afternoon.'],
#  ["Derek and Alyssa make fun of Fergie's performance of the national anthem."],
#  ["Pam doesn't have rota for Lauren, but Manager may give Lauren more tomorrow",
#   "Pam and Lauren will meet tomorrow and discuss Lauren's holiday",
#   ''],
#  ['Jamie has never gone ghost hunting but Harriette did with her friends once in high school',
#   "They did not see any ghosts and she only got frightened by a cat's miaowing."],
#  ["Jack needs Kev's help as he cannot get the application running", ''],
#  ['Dan wants to apologize to Angela', 'They will meet at school later.'],
#  ['Shaldona sends mobile invitations to her wedding, as she has no time to give them in person.'],
#  ['Paula and Ralph will meet the new person in an hour', ''],
#  ['Ania, Kasia, Zuzia and Jan want to go to the church tomorrow',
#   'Ania and Zuzia do not find it appropriate to go to the church with a boy.'],
#  ['Harry waits outside',
#   'The movie has already started but Ema needs another 5 minutes, which made Harry angry.'],
#  ["In the agreement it was decided that it's neither a sea nor a lake and it will have a special legal status",
#   'They will also completely divide the seabed up',
#   "It's rich in resources, mostly gas and oil."],
#  ["Joe's job is wearing him up",
#   "Tim's friend Terry quit his job because he was burned out."],
#  ["Natalie is checking if it's worth going to the new club at Regents Street",
#   'Denise thinks the club is great',
#   "Judy's friends also recommend the place, so Judy is going there this weekend",
#   'Natalie will go to the club with Judy, Miranda and Helen on Saturday.'],
#  ["Jamie, Marlo, Jimmy and Alex's teacher requires their class to divide into 2 groups, each making a presentation",
#   'The teacher sent them the presentation subjects via e-mail',
#   'Jamie, Marlo, Jimmy and Alex consider dividing the class into groups by gender',
#   ''],
#  ['John is in the park', 'He is leaving now.'],
#  ['There was a crowd outside the bookshop today',
#   'Cole Grant, who writes about vampires, was allegedly in the bookshop signing his books.'],
#  ["Debbie can't decide between buying a red dress and a green one",
#   "On Kelly and Denise's advice she will buy the green one",
#   'Kelly is considering buying the red one for herself.'],
#  ['Emilia is still angry.'],
#  ["Tom will help Mia buy a flight ticket as she doesn't have a credit card and doesn’t want to use Peter's now",
#   'Tom needs the flight, company and your personal data.'],
#  ['Hugh has a toothache and needs to go to the dentist',
#   'Andy and Wade recommend him dentists at ProDent',
#   'Hugh will call ProDent today.'],
#  ["Before Christmas, Ella's mom won a hundred thousand in a lottery",
#   'Both Ella and Noah are excited.'],
#  ['There has been an accident on Circle Drive, neat Circle Mall',
#   'There are no fatalities.'],
#  ['Rob and Bob are watching the game',
#   'Bob will run some errands on the weekend',
#   "Jim's birthday is next Wednesday",
#   'He might organize a meetup this weekend',
#   'Bob will see Rob on the weekend.'],
#  ['Julie and Debra are discussing the event, there will be about 20 people, mostly girls from the village 40+.'],
#  ["Mike's had an accident on his motorcycle and he's broken his leg."],
#  ["David was looking after Ethan's sister",
#   'Ethan is grateful',
#   "David won't do it again",
#   ' '],
#  ["Conrad can't enter the house because he forgot his keys",
#   "Since Rebecca and Tiffany are coming back late, he'll wait in the coffee shop",
#   ''],
#  ["Clara and Ron are wondering what that weird smell at Kasia's place last night was."],
#  ["Holly is not feeling very well, so she's not coming to Jake's tonight", ''],
#  ["Ludmila's favourite dinosaur when she was little was the Triceratops."],
#  ['Josh, Sean and Logan are going to the pub tonight to pick up some girls',
#   "Logan doesn't want Sean to scare the girls away with his inappropriate comments."],
#  ["Someone left a phone at Liam's place, but it wasn't Indiana."],
#  ['Claire is ordering her wedding dress, adviced by Maria and Nicole.'],
#  ["Victor took over Chris's company, which was under a huge debt",
#   'He sold the office and did some changes but Chris still works there as Director',
#   "David's business goes very slow but he expects it to get better by the end of the year."],
#  ['Patricia is recommending a fair-trade brand to Elle and Florence.'],
#  ["Ethan didn't come to the party last night because he is in Los Angeles",
#   "Abigail didn't know about it",
#   'Ethan will be back in a couple of days, the he will reach out to Abigail.'],
#  ["Stan is meeting the girl of his dreams today in Pat&Gill's",
#   "Later he's going to tell Dave how his date went."],
#  ['Miro speaks Albanian with his parents',
#   'His family left Albania illegally in 1990s.'],
#  ['Julie has just watched a Japanese horror',
#   "She's alone at home and really scared",
#   'Paula and Rose are going to come to her place for a spontaneous sleepover',
#   'They\'ll drink cocoa and watch \\"When Harry met Sally.\\" Rose will bring cookies.'],
#  ['Lucy is panicking because her daughter is 15 now and she is not sure she is prepared as a mother.'],
#  ['Dan,Tim, Chris and Martin will meet at 8',
#   'Dan and Martin will take it easy this time',
#   "Tom can't make it as he has a party at in-laws."],
#  ['Casey got a new nail polish and did her nails herself',
#   "It took her nearly 4 hours, so she won't do her friends' nails, as it takes too long."],
#  ['Sharol forgot about her sociology assignment',
#   "She needs to research feminist act, and it's due tomorrow",
#   'Kate has already finished it, and she rushes Sharol.'],
#  ['Jack had to miss school because he is sick',
#   'Jamie was sick a lot last year but he got better thanks to doctor Tornez at City Medical Centre, next to the mall',
#   'Linda learns the school trip has been cancelled as many students are sick.'],
#  ['Tim does not need mum for anything important at the moment.'],
#  ["Kate believes her boyfriend's mother dislikes her",
#   'He is a nerd who lives and has always lived with his mother and grandmother.'],
#  ["Vincent's new lamp should be ready to be picked up on Tuesday."],
#  ['Nestor wanted to buy a laptop on Black Friday sales, but Olaf advise against it, as the prices in reality are not reduced',
#   'Nestor will check it if Olaf helps him to get a good deal from a guy he knows.'],
#  ['Nancy asks Vic and Phil about various social media, which prompts them to discuss and compare the different platforms',
#   'Phil is not into Instagram but likes Twitter',
#   'Vic prefers Facebook over Twitter and likes Instagram',
#   "Phil and Vic both don't use Tumblr",
#   ''],
#  ["Amanda and Peter don't like what the man in dreads looks like, but Dan does."],
#  ['James will pick up the car after his work tomorrow',
#   'Sue already have sent him money',
#   ''],
#  ['Jess is in a traffic jam in West Bronx.'],
#  ["Dima's laptop is broken, as her cat spilled coffee on the laptop",
#   'Dima is worried, because she has to deliver a translation for Trados tomorrow',
#   "Dima will come to Nada in an hour to borrow Nada's laptop",
#   ''],
#  ['Afterwards, Kelly wandered around and met some people from school',
#   'She also met him',
#   "They almost didn't talk and he was with someone",
#   ''],
#  ['Anne is inviting Adele for Easter',
#   'Adele will bring some chocolate eggs.'],
#  ["Melody's 5-year-old laptop is broken",
#   "Tomorrow she'll know what's wrong",
#   "She won't be repairing it, because her laptop is too old",
#   "Instead, she'll buy a new one."],
#  ['Jerry will be home in 40 minutes', ''],
#  ['They are going to do some research on holiday options and discuss them later',
#   'They will most likely choose a cheap offer from a tour operator.'],
#  ["Del accused Stanley of having an affair, because he couldn't go with her this weekend due to his work",
#   "They've only been together for 4 months, so it's not a good sign",
#   'Now Bill and Stanley need to take care of the Lidem project',
#   'Division of tasks is on Stanley, because Alison is unreachable.'],
#  ['Kimberly might have left her umbrella she got from her mother at the cafe yesterday',
#   "Laura gives her the cafe's phone number to check with the staff."],
#  ['Catherine applied for an accounting position at Pandora',
#   'Jake has been working there for 5 years',
#   'This job offers a clear career path and benefits',
#   'Jake got promoted twice with salary increase',
#   'Catherine will have an interview on Monday.'],
#  ['Anna will go with Fiona to a doctor tomorrow at 8 a.m.'],
#  ['Pipe under the wash basin exploded when Dan wanted to wash his hands',
#   'Andrea is going to write to the owner about it.'],
#  ['Both Claire and Linda are making curry for dinner', ''],
#  ['Matt will be staying with homestay parents for one more month',
#   'They seem to talk more to Carlos',
#   'They have higher electricity bills because Matt spends a lot of time at home.'],
#  ['Ann thanks Katie for hosting her son Tim on Monday evening and driving him to the railway station next morning',
#   'Kate will send a message to Tim tomorrow, to ask about the place where she should be waiting for him.'],
#  ["Ahmed wants Sharon to move in with him but she's afraid of her parents' reaction",
#   'Ahmed is angry.'],
#  ['Rob is disappointed with memes he watches',
#   'Tom suggests he should get a girlfriend instead of complaining about the memes.'],
#  ["Mike will refill the hand sanitizer on Grace's request."],
#  ['Cheryl had an argument with her mom',
#   'She forgot to close the window, got angry and started a fight',
#   'Her mom gave her time till the end of the year to move out.'],
#  ['David lands at 17:30 at Sevilla airport and Victor will pick him up.'],
#  ["Ann wants to buy Josh's laptop for $200",
#   "Josh doesn't want to negotiate the price",
#   'Ann will take it for $250 with accessories',
#   ''],
#  ['Mike wants someone else to do the washing up this time',
#   'Sara agrees, but when she returns from the cinema she is at with Jack.'],
#  ['Gary is a driver for Uber and he really enjoys it.'],
#  ['Kristi needs new trainers',
#   'Leah has a link for a discount coupon at an online store.'],
#  ['Steve is calling Sue at her request.'],
#  ['Andre is shocked after reading the news about a bear attack at the zoo',
#   'Megan is not surprised that an animal kept in a cage reacted that way.'],
#  ['Barbara got the confirmation email from AES',
#   'Mick did not get the email and will call them.'],
#  ['Allison send Alan budget estimation for this year',
#   "Extra other expenses are boss's trip to Japan, for a convention."],
#  ['Liam and Nate will meet spontaneously in 15 minutes.'],
#  ['Carl will compete in championship this year',
#   "Duncan can't miss this event",
#   'Carl will register his family members as VIP.'],
#  ["Dinny's afraid of Terry's dog so he should keep it away."],
#  ['Anastasia sent her new school photos to Darrell.'],
#  ['Kim is going with Jane to Seoul in April',
#   'Jane will be their tour guide.'],
#  ["Dad of Aubrianna's friend died of malaria in Kongo."],
#  ['Josh is upset, because he lost his new sneakers on Tuesday',
#   "Josh has already called the gym, but they didn't find anything",
#   'Josh will check the swimming pool and give Mark a call.'],
#  ["It's Valentine's day",
#   'Bella plans to order some pizza home',
#   'Aria will come to Warsaw as soon as she quits',
#   'This year Bella will probably go to Korea to get regular checkup',
#   ''],
#  ['No one wants to play ball with Sawyer tonight.'],
#  ['Daina needs about an hour more to get ready.'],
#  ['Viola is having her wedding soon and still has some things to organize',
#   'Carmen comes on Friday and is willing to help Viola.'],
#  ['Madeline is in conflict with Martin and Jada',
#   'Alex and Madeline will go for a beer tomorrow',
#   'Madeline will explain her issues with Martin and Jada to Alex.'],
#  ['Mom wants Betty to call the grandfather from time to time.'],
#  ['William is making spaghetti alla vongole for dinner',
#   "It's an Italian dish and it involves pasta, garlic, wine and clams."],
#  ['Maria suggests to meet after the IMF lecture to discuss the presentation which is due on Monday',
#   'Maria, Alexander, Martha and Sarah will meet tomorrow at 17:15',
#   'Lawrence will be late.'],
#  ['Molly and Anna will go to the Muse concert in Cracow.'],
#  ['Tabby has 2 exams next week',
#   'Laura passed all her exams but one',
#   "Tabby may come to Daisy's party on Saturday, depending on her studying progress",
#   ''],
#  ["Becky and Trent are taking care of Joel's cat Coco",
#   'Coco likes them both and is behaving rather well so far',
#   ''],
#  ["Sosie will be at Kyra's flat in 5 minutes", 'The flat number is 187.'],
#  ['Ronnie uses three different bins for waste',
#   "He doesn't use straws, neither plastic bags",
#   'Clint and Ronnie agree that environment protection depends on the government',
#   ''],
#  ['Adam called Tina',
#   'She is at work',
#   "Her cell's battery's low",
#   'She will cal Adam later in the evening or tomorrow after 9 am.'],
#  ['Natalie is pregnant with Dave',
#   "Jane didn't think Sally should share it with others as Natalie told them that in confidence",
#   'Henriette and Greg are surprised that the father is Dave not Mike.'],
#  ['Nick will got some lunch for Steve - it can be anything but chicken', ''],
#  ['Gemma will invite Timmy and his Date, as well as Lona and Michelle to her wedding.'],
#  ["Millie is sick, so she won't come today."],
#  ["Lisa isn't going home yet", 'Daisy wants her to be back before 11 p.m.'],
#  ['Tina will make it for the bus that is leaving in 3 minutes.'],
#  ['Sophie accepts some quince from Noah',
#   'Noah has left the quince in a basket on his terrace and the twins can pick it up any time',
#   'The twins are in college',
#   "Noah's son is in the military",
#   'He is still single but reportedly not gay.'],
#  ['Harry goes to Ikea',
#   'He will buy some furniture, frozen cake and a bag of meatballs for Sarah',
#   'Harry will use Sarah’s Ikea Family card.'],
#  ["Cindy is sad, but doesn't want to talk about the reason",
#   "Ellie hasn't seen the funny video that went viral",
#   ''],
#  ['Jannet thanks Nadia for coming to her place yesterday',
#   'Nadia enjoyed the party and is still in a dancing mood',
#   'They are going to the disco next time.'],
#  ['Jeff and Mark are amazed by his car',
#   'They bet 100 dollars who gets to drive it first.'],
#  ['Ann, Sue and Julie did a great job and they will have a little celebration tonight.'],
#  ['Kathy had her hair cut.'],
#  ['Claudia, Andy and Mark stayed after hours at Mr',
#   "Benson's request",
#   'Mr',
#   'Benson is currently discussing a contract with a new client in Per and he wants to organize their work remotely.'],
#  ["Jane thinks Den's mum needs to get out more, so Den suggests to invite her for tea, fish and chips on Friday after work."],
#  ['Mum is at school in front of the door',
#   "Ludo's rooms is 112 and his class is class 3",
#   'The same goes for Hugo and Charles',
#   'The building is big and has a big garden',
#   'The meeting is about to start.'],
#  ['Chandler asks Phoebe to open the door and pay the delivery guy standing outside his door.'],
#  ["Max's sister is studying in Shanghai and she already speaks Chinese",
#   "She doesn't find the whole experience amazing but she believes it's a good investment."],
#  ["Russ received David's report but hasn't read it yet."],
#  ["Ben won't go with Catherine to visit uncle Steve",
#   'He will visit her and the boys',
#   ''],
#  ['Kaya is looking for Clay, who is in the classroom.'],
#  ['Alice and Sean will wash the car on their way tomorrow.'],
#  ['Julia will be waiting for Bert with the dinner',
#   'Bert is coming home around 8.'],
#  ['Steve is happy that he got a new dishwasher installed.'],
#  ['Michelle is still researching and Harvey cannot wait all day for the update',
#   "Michelle can't see most of the things as it's black hat and it installs bugs on her computer."],
#  ['Joy is coming back on Thursday.'],
#  ["Julia was at cafe Kohaku near Covent Garden last week, but it's closed down now to her and Henry's surprise",
#   "She contacted the owners, but they haven't replied yet",
#   "Henry and his cousin went to the Lily's in the end, but it had a different vibe."],
#  ['Olivia has to sort out her accounts and upload a few videos on YouTube',
#   'Jake is complaining that Sony Music tried to appropriate his own music.'],
#  ["Emily's a guest at Linda's house",
#   "She broke one of Linda's green tea cups when she was cleaning the cupboards",
#   "Linda doesn't like them and she offers Emily the whole set."],
#  ['Camilla and Tom will go to Dublin this weekend.'],
#  ["Stella doesn't want to visit Sandra because she doesn't want to get infected by Sandra's disease",
#   "Sandra's doctor prescribed her effective medicines, so she will be fine soon",
#   'Stella wants to take Sandra to the cinema for some action movie when she recovers.'],
#  ['Harley and Ruby are discussing the divorce filing',
#   'Harley and Ruby agree there are always two sides.'],
#  ['Ken feels stressed because of work and fighting with Brad',
#   "There is also too much going on at mom's",
#   'Ken is going to a show on Saturday night',
#   'On Sunday Ken is seeing the grandkids at the zoo.'],
#  ["It's derby day today",
#   'Titus supports Manchester United',
#   'Julius supports City.'],
#  ["Addisyn hasn't talked to Dexter for a long time and he thinks she doesn't love him anymore."],
#  ["Jason had a dental appointment today and that's why he was absent."],
#  ["Cindy has made arrangements for today's meeting at 2 pm in the conference room",
#   "She also organised flights and hotel for next week's trip",
#   'Don is appreciative',
#   ''],
#  ['Samuel ordered a smoke.'],
#  ['Mike considers going to Egypt for holiday',
#   "It's too hot for Celia, she suggests Croatia instead",
#   "Mark likes the idea, he's never been there",
#   ''],
#  ['Jasmine loves Charlie Puth and his new song',
#   'Paola thinks Charlie Puth is attractive',
#   'Paola likes the song \\"Galway Girl\\" by Ed Sheeran.'],
#  ["Jaz will come to dye Sharon's roots on Sunday at 2.30."],
#  ['Pete will be home for lunch in about 20 minutes.'],
#  ['Laura wants Kas to tidy up her dreads this weekend',
#   'Kas will let her know tonight if she is available.'],
#  ['Jill did 20 or 30 so far, 3-4 per day, 40 or 35 hours, so the same as Ally.'],
#  ['James and Mia want to go to an art exhibition tomorrow',
#   "James wants Amelia to go with them but Mia isn't sure about it",
#   'James and Mia will go to his place afterwards.'],
#  ["Chae-yeong and Arthur inform Mariana that the readings for the next session of Stephen's seminar weren't available in the print shop on Monday",
#   "Rita decides to go and chcek if the situation's changed tomorrow and she'll let everyone know."],
#  ['Ost bought a garage place for a good price',
#   'He intends to rent it out',
#   'He thinks it will be a better deal than keeping savings in the bank',
#   'The prices of garage place in Belgrade will grow as there are more and more vehicles.\\n\\n'],
#  ['Hania has been traveling for 3 hours already',
#   'She will get there around 7pm',
#   'Julia will order takeaway pizza for her',
#   ''],
#  ["Kaylee is blocking Gavin and Gavin doesn't care as he finds Kaylee too much irritating."],
#  ['Marika is coming today.'],
#  ['Mazie and her girlfriends are having a drink tonight',
# ...
#   'Jackie is worried about her financial situation.'],
#  ['Sean never gets up for the morning lecture',
#   'He needs to attend it at least once to get the notes.'],
#  ["Anna got an awful stomachache at night but she doesn't know its cause",
#   'Her mom Joanna will make her hot tea with some fresh mint leaves.'],
#  ['Ziggler will bring the passport tomorrow as reminded by Dolph.'],
#  ['Kate and Jeff are downstairs in a room next to the reception',
#   'Some lady is making a marzipan cake',
#   ''],
#  ['Larry has to read the E-mail again and make a decision with Kirsten afterwards',
#   'Kirsten has to convince her husband',
#   'Kirsten wants to include Jamie and John',
#   'Larry and Kirsten are going to arrange menorah in the lobby.'],
#  ['Somebody has to take the dog out',
#   'Chloe wants to go to Megan tonight and the father has to work late tonight',
#   'Chloe will have to come back home to let the dog out and then she can see Megan.'],
#  ["Natalie's wallet is in her room."],
#  ['Rob is looking for Phil',
#   'Rob needs to talk with him',
#   'Phil will come over to his office tomorrow morning.'],
#  ['Martin is asexual',
#   "Nicole doesn't want to break up for this reason",
#   'She wants to give their relationship a try.'],
#  ['Mike suspects he might have had an allergic reaction to something.'],
#  ["David wants to get a new tattoo but he doesn't know what exactly yet."],
#  ['William is making spaghetti',
#   'Olivia will buy fresh tomatoes for William',
#   'Beth will buy chocolate.'],
#  ['Karen got stuck on the road from the swimming pool to Waitrose so wants Peter to avoid it',
#   'Peter is not leaving until 6 as he he has to finish his presentation',
#   'Karen will see Peter in a bit.'],
#  ['Nick will let Matt know when he remembers what their internet connection is.'],
#  ['Baron, Gabriel and Gavin have a match next week',
#   'Their tutor wants to join them.'],
#  ['Mia, Jennifer, Karine and Peter do not like Trump.'],
#  ['Madison considers buying flight tickets to Thailand as she has found a cheap offer with 50% discount for children under 12.'],
#  ["Tina has to learn Demi's approach how to transfer from hating men to dating them."],
#  ['Winnie has broken her leg and will not visit any time soon',
#   'Freddie will ask mummy to call Winnie up.'],
#  ['Mark, Clint and Phil are going to watch \\"Batman',
#   'New Beginning\\" on Saturday, at 7',
#   'Mark will get the tickets.'],
#  ["Betty's house has mould due to condensation",
#   'Andy will send her a quote for the work needed by Friday.'],
#  ['Warren locked the door.'],
#  ['Aaron will give two lectures during the conference about relations at school at the Sesame Street',
#   'Claire will participate in mindfulness workshop.'],
#  ["Rob wants to sell his flat, because it's too small",
#   'Rob will meet a friend tomorrow who has a flat to sell.'],
#  ['Evan will try to make Ethan come.'],
#  ['Daisy is in Naples',
#   'Charlie recalls their meeting and wants to see her again',
#   'He will come to Florence to see Daisy between 1-5 September.'],
#  ['Adele is still listening to the song which Code recommended',
#   "Kode will come to Adele's home today and will give her the whole album of the same singer",
#   ''],
#  ['Maddie is confused, because Leah told her that Ian was dating a girl named Claire',
#   'Ian met Claire about 1,5 years ago, but they barely knew each other.'],
#  ['Violet will make an appointment at a waxing salon',
#   "Home methods don't work for her."],
#  ['Suzy urges Linda to follow her on Instagram and she obliges.'],
#  ['Sean reminds the guys about trade deadline today',
#   'Rick wants to vote',
#   'John will look at it after the season.'],
#  ['Lisa is no longer interested in the diet now Amelia has informed her that her mum put on weight doing it',
#   ' '],
#  ['Carrie and Gina saw \\"Fantastic Beast\\" and liked it',
#   'Ginna loved Eddie Redmayne as Newt',
#   ' '],
#  ["Emily's favorite color is blue",
#   "Amelia can't talk about the reason behind her question with Emily."],
#  ['Mary moved to Southampton in December.'],
#  ['He is no longer the teacher of Shanon, Victor, Oliver and Sid',
#   'He got fired today.'],
#  ['Alex prefers the Flash to Barman and Superman thanks to his speed.'],
#  ["Marek sent Adam a photo of man's bottom",
#   'Marek made this photo in the shopping mall, on the escalator',
#   ''],
#  ["Daniel's sister is visiting him",
#   "Daniel and Mark will meet at Mark's place for drinks."],
#  ["Bart didn't do well this semester because he didn't study much",
#   'He played a lot fo StarCraft',
#   'Adrian did well thanks to paying attention in class'],
#  ["Margot bought a bottle of nice wine for Nancy's birthday."],
#  ["Amelia thanks Lindsay for coming to Elliot's birthday."],
#  ['Jennifer, Jack and Reece will match the latest Mad Max on Netflix tomorrow evening',
#   'Jack has already seen it.'],
#  ["Sean believes his spirit animal is a tortoise and Tiffany's could be a wasp",
#   ''],
#  ['Mary is back', "Mary's baby, Susie, is doing great."],
#  ["Patti and Greg's cat is getting better, so Patti will pick it up later",
#   'Patti will come back home at around 5 pm.'],
#  ['Kate is buying apples for herself and George',
#   'They have to wait for tangerines until next week.'],
#  ['Sam bought the earphones which cost him £187 along with delivery expenses',
#   'The order should be delivered the next day.'],
#  ['Kelly and Mary will wear red dresses',
#   'Mary will wear a red lipstick too',
#   ''],
#  ["Kate wants to borrow Emily's blue handbag as she needs it for Monica's wedding",
#   'Emily will bring it with her to the office tomorrow',
#   ''],
#  ["Gina will come to room 112 on the 2nd floor to pick up Monica's usb", ''],
#  ['Nathan is planning on buying a bike in spring',
#   'He will probably store the bike on some special hooks because his apartment is small',
#   'Nathan has also bought a stationary bike to keep fit.'],
#  ['Parker and Jason both prefer DC Universe to Marvel',
#   'Jason is still downloading the latest episode of Arrow season 7',
#   ''],
#  ['Michael is returning from trip to Argentina, Brazil and Chile',
#   'He will be in Boston next weekend',
#   "Michael doesn't like his job, he thinks of quitting it and leaving London",
#   "Kai's been very busy recently",
#   'She has a conference on 8th of December.'],
#  ['Carol will collect the excess fruit on Wednesday at 6 pm.'],
#  ['Luca wants Molly to try harder.'],
#  ['Janette has mice in her kitchen.'],
#  ["Lawrence's almost done with the article, Madison needs it today."],
#  ['Julia will call Ronald when she gets back',
#   'He has something to tell her.'],
#  ["Agata has a new job, she's learning to code and she likes it",
#   "Guido doesn't understand her Facebook posts because he knows nothing about JavaScript."],
#  ['Alejandro and Luz are going to meet in 2 weeks for the first time',
#   'Luz knows Alejandro very well already',
#   'They talk about everything',
#   'Luz will be there on the 20th of December at 4PM',
#   'Alejandro will pick her up.'],
#  ['Sam started a career mode in FIFA.'],
#  ['Ethan will buy Damian a kebab', 'Damian had a bad day.'],
#  ["Adam hasn't visited his parents in six months and is coming over tomorrow",
#   'His flight will land an hour later than originally scheduled',
#   'Hannah will let Dad know.'],
#  ['Matthew has a cold', 'He will drink some orange juice and go to sleep.'],
#  ["Joyce wants to take Kyle's car to get Harry",
#   'Kyle is taking the car to a mechanic',
#   'Joyce refuses to get Harry by bus',
#   'Kyle agrees to pick Harry up',
#   ''],
#  ['Bailey has plenty of clothes but she keeps buying new ones and she even had to buy four extra boxes for clothes at Ikea',
#   'Mikaela has the same problem, but she only had to buy one extra box',
#   ''],
#  ['Toby proposed to Susan during their romantic weekend in a cosy hotel near the beach.'],
#  ['Eva is at a party, while Olivia is taking care of her daughter, Linta',
#   'Eva will leave soon and pick Linta up.'],
#  ['Laura and Jack are about to meet', 'Jack is running 10 minutes late.'],
#  ['Michelle is not in favor of contemporary feminism movement.'],
#  ['Franks tells Zoe he loves her.'],
#  ['Josie finds Eco\'s novel \\"Foucault\'s Pendulum\\" nerdy',
#   "Josie would like to read Eco in Italian, but she's unsure of her language abilities",
#   "Stefano considers Eco's two novels and finds them difficult",
#   'Josie has read an unfavorable review of \\"Foucault\'s Pendulum\\" by Salman Rushdie.'],
#  ["Evan can't come to his lesson tomorrow, because he's got the flu."],
#  ['They will meet around 9 pm tonight to attend a free concert in the City Park.'],
#  ["Bobby's most annoyed by pharmaceutical companies",
#   'He believes they invent diseases to make money',
#   "He discovered that one company is selling mints as medicine for an illness that doesn't exist."],
#  ['Greg sent Dave his notes from statistics.'],
#  ["Sally is not going out because she doesn't feel well", ''],
#  ['Sandy will go for a run',
#   'She will meet Joy after 11am',
#   "Lina and Joy don't think the dresses are appropriate",
#   'Joy will wait for Sandy.'],
#  ["It's raining, so Val and Candy will wait half an hour before they go."],
#  ['Susie found the plasters and Ted kept them until the morning.'],
#  ['Mary and Lily will call Kyle on facetime.'],
#  ['Harry will go to Taylors party tomorrow at 8pm', ''],
#  ['Tomas, Sierra and Jeremy have still not received the grant',
#   'Tomas is broke and is checking his bank account every hour',
#   'Sierra offers to lend him some money.'],
#  ['Camilla has some errands to do on Saturday',
#   'Charles is visiting the German markets this weekend',
#   'They are talking about Christmas food and drinks.'],
#  ['Pamela will look at their website to apply for the RGS grant',
#   "Zoe and Xiara applied last year but they weren't lucky",
#   'Sometimes you have to be a member to apply.'],
#  ['Colin informs Ava that with her height of 158 cm she is shorter than an average penguin.'],
#  ['Ursula got 93 on her French exam', 'Vaughn got 65, but still passed.'],
#  ['There was a drill at the school today.'],
#  ['Perry, Marlow, Janet and Forster discuss their holiday plans',
#   'Marlow would like to go to Asia, others will think if they can join',
#   'The friends will meet tomorrow at 8 pm to discuss that',
#   ''],
#  ['The client manager suited up',
#   'He has a presentation for a client',
#   'Lee pre-ordered the digital RoS CE and got extra in-game content: Wings and a Demon Hunter for Heroes of the Storm.'],
#  ['Maya wants Boris to bring clothes that are hanging outside',
#   "Brian will do that, because Boris isn't at home now."],
#  ["Barry, Dave, Kelly, and Jake will meet around the campus at 12 to join Women's strike."],
#  ['Laurel and John meet at Jades tomorrow at 5 pm to buy a birthday gift for Diana',
#   "Diana's birthday is on Saturday."],
#  ['Rachel has a new siamese cat, a girl called Portia',
#   'Rachel discovered that is allergic to cats',
#   'She is sneezing, has rashes and other allergic reactions',
#   'She takes medications that seem to help',
#   'Adam consoles Rachel.'],
#  ['Mark is planning an afterparty after his wedding',
#   "It's going to take place at their house on the next day."],
#  ['Diana and Russel are buying a present for mum.'],
#  ['Amy has severe aura', 'Penny, Owen and Neil want to meet her in person.'],
#  ['Rachel and Wai will go to the museum together',
#   'They will go to a bar then',
#   "Rachel will meet Wai's friends for the first time."],
#  ['Robert is out of town.'],
#  ['Dorothea is having a birthday dinner in the town with Tom',
#   'Elena is seeing Dorothea at her party on Saturday',
#   ''],
#  ["Jules and Derek don't have class tomorrow as it's Friday."],
#  ["Ainsley is sick, so she's not able to help Jane with her thesis now."],
#  ["Felipe finds Lydia's legs attractive",
#   'She has been working out at the gym for months.'],
#  ["Mick's never done any student exchange before, but Amka did",
#   "Mick had a plan to go to London for Halloween, but he's not going because of his grandma's health problems",
#   'Amka will stay in as well',
#   'Mick tells Amka about Halloween in Poland.'],
#  ['Jessie and Karine went together to the kindergarten.'],
#  ["Cael lets Mae know that the dress isn't ready yet."],
#  ['Fiona fell in love with his student, Conrad.'],
#  ['The situation in Kongo is terrible because of its resources and politics.'],
#  ['Margaret and Evans plan to meet at 10 on 4th and at 11 on 11th',
#   'They both are not sure when they will be able to meet next, so they will come up with a date later.'],
#  ['Bradley is too busy at work to talk to Joanne now.'],
#  ['Pete has got an interview',
#   'His wife Iris is happy because her parents are glad she found a decent man',
#   'She is joking he is famous.'],
#  ['Iris is trying to remove herself from an expense',
#   'Ken has fixed the problem',
#   'Julia will be added to the expense again later',
#   'Gerardo will ask the people leaving early to stay in the splitwise group until the end of the month',
#   'George will stay.'],
#  ['Ola should be free by 8', 'Kurt wants her to call him.'],
#  ['Conny cannot find enough information online for his paper',
#   'Fitz suggests he tries the library',
#   ''],
#  ['By looking at the photos, Archie thinks that Melanie looked nicer with curly hair',
#   'Louis disagrees.'],
#  ['Carly and Cindy think she is stupid, because she asked him', ''],
#  ['Kirsten reminds Alex that the youth group meets this Friday at 7 pm and go bowling.'],
#  ['A boy that Sam likes is not talking to her, but Cathy convinces her that he likes her',
#   'Sam will talk to the boy tomorrow.'],
#  ['Jess dreamt she was a lion tamer',
#   'Lynn believes that dreams mean something',
#   "Charlie has read that strangers from our dreams are actually people who we've seen before."],
#  ['Coeliac disease makes it impossible to digest gluten',
#   'Charles feels bloated and gained weight recently',
#   'Monica stopped eating lactose',
#   'Charles had a blood test.'],
#  ['Ulysses and Peter got an A, Julia got a B',
#   'The grades are to be checked on the course page.'],
#  ['Ralph told Andrew a joke.'],
#  ['Linda missed her train and the next one is in one hour',
#   'A return to Amsterdam was 80 euros.'],
#  ["Martha likes Ophelia's lenses and wants to buy similar ones",
#   'Ophelia got them from Crazy Lenses.'],
#  ['Linda wants to buy flowers for her mother and asks Michael which flowers does she like',
#   'Michael suggests Linda to buy freesias.'],
#  ['Tim is running late and will arrive around twenty past',
#   'He asked Gary to do some small talk and try to delay the main presentation.'],
#  ['Marcus will pick Mark from the airport at 4pm',
#   "Anna will call Mark and give him Marcus' number."],
#  ['Lewandowska has measles',
#   'There are vaccinations in the main building from 17th until 19th for everyone who had contact with her',
#   ''],
#  ['Louisa will lend Thelma her red velvet dress.'],
#  ["Megan and Joseph will take Joseph's car to the opera."],
#  ["Carl is waiting for Meg who's running late as she can't find her key", ''],
#  ["Ben is having a downtime, isn't very talkative",
#   'Kim wants to see Ben tonight but he has to rain check.'],
#  ['Stan Lee is dead.'],
#  ['Maria is tired of her job', ''],
#  ['Ryanair has canceled many flights', 'This affected Erin, Luke and Ava.'],
#  ["Rachel's aunt had an accident and she's in hospital now",
#   "She's only bruised",
#   'The perpetrator of the accident is going to pay for the rehabilitation',
#   ''],
#  ['Monica had sex with Ross at an office party two months ago',
#   "She's pregnant, but didn't tell Ross about it, who's married."],
#  ['Luke will go surfing at 2:22 pm tomorrow.'],
#  ["Benjamin didn't come to see a basketball game on Friday's night",
#   'The team supported by Alex won 101-98',
#   "Benjamin's mom has a flu and he's looking after her",
#   'Benjamin declares to attend the next basketball match.'],
#  ['The audition starts at 7.30 P.M', 'in Antena 3.'],
#  ['Marta sent a file accidentally,'],
#  ['There was a meet-and-greet with James Charles in Birmingham which gathered 8000  people.'],
#  ['Rachel sends a list of Top 50 films of 2018',
#   'Janice watched almost half of them, Deadpool 2 and Avengers included.']]
